# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\saman\anaconda3\lib\site-packages (1.5.0)
# Requirement already satisfied: pillow in c:\users\saman\anaconda3\lib\site-packages (from wordcloud) (5.1.0)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\saman\anaconda3\lib\site-packages (from wordcloud) (1.14.3)
# distributed 1.21.8 requires msgpack, which is not installed.
# You are using pip version 10.0.1, however version 19.0 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %% [markdown]
# ## 1. Loading the NIPS papers
# <p>The NIPS conference (Neural Information Processing Systems) is one of the most prestigious yearly events in the machine learning community. At each NIPS conference, a large number of research papers are published. Over 50,000 PDF files were automatically downloaded and processed to obtain a dataset on various machine learning techniques. These NIPS papers are stored in <code>datasets/papers.csv</code>. The CSV file contains information on the different NIPS papers that were published from 1987 until 2017 (30 years!). These papers discuss a wide variety of topics in machine learning, from neural networks to optimization methods and many more.
# <img src="https://s3.amazonaws.com/assets.datacamp.com/production/project_158/img/nips_logo.png" alt="The logo of NIPS (Neural Information Processing Systems)"></p>
# <p>First, we will explore the CSV file to determine what type of data we can use for the analysis and how it is structured. A research paper typically consists of a title, an abstract and the main text. Other data such as figures and tables were not extracted from the PDF files. Each paper discusses a novel technique or improvement. In this analysis, we will focus on analyzing these papers with natural language processing methods.</p>

# %%
# Importing modules
import pandas as pd
import matplotlib.pyplot as plt

# Read datasets/papers.csv into papers
papers = pd.read_csv('datasets/papers.csv')

# Print out the first rows of papers
print(papers.head())
# Out:
#      id  year                                              title event_type  \
# 0     1  1987  Self-Organization of Associative Database and ...        NaN
# 1    10  1987  A Mean Field Theory of Layer IV of Visual Cort...        NaN
# 2   100  1988  Storing Covariance by the Associative Long-Ter...        NaN
# 3  1000  1994  Bayesian Query Construction for Neural Network...        NaN
# 4  1001  1994  Neural Network Ensembles, Cross Validation, an...        NaN
#
#                                             pdf_name          abstract  \
# 0  1-self-organization-of-associative-database-an...  Abstract Missing
# 1  10-a-mean-field-theory-of-layer-iv-of-visual-c...  Abstract Missing
# 2  100-storing-covariance-by-the-associative-long...  Abstract Missing
# 3  1000-bayesian-query-construction-for-neural-ne...  Abstract Missing
# 4  1001-neural-network-ensembles-cross-validation...  Abstract Missing
#
#                                           paper_text
# 0  767\n\nSELF-ORGANIZATION OF ASSOCIATIVE DATABA...
# 1  683\n\nA MEAN FIELD THEORY OF LAYER IV OF VISU...
# 2  394\n\nSTORING COVARIANCE BY THE ASSOCIATIVE\n...
# 3  Bayesian Query Construction for Neural\nNetwor...
# 4  Neural Network Ensembles, Cross\nValidation, a...

# %% [markdown]
# ## 2. Preparing the data for analysis
# <p>For the analysis of the papers, we are only interested in the text data associated with the paper as well as the year the paper was published in.</p>
# <p>We will analyze this text data using natural language processing.  Since the file contains some metadata such as id's and filenames, it is necessary to remove all the columns that do not contain useful text information.</p>

# %%
# Remove the columns
papers = papers.drop(['id','pdf_name'],axis=1)

# Print out the first rows of papers
papers.head()
papers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7241 entries, 0 to 7240
# Data columns (total 5 columns):
# year          7241 non-null int64
# title         7241 non-null object
# event_type    2422 non-null object
# abstract      7241 non-null object
# paper_text    7241 non-null object
# dtypes: int64(1), object(4)
# memory usage: 282.9+ KB

# %% [markdown]
# ## 3. Plotting how machine learning has evolved over time
# <p>In order to understand how the machine learning field has recently exploded in popularity, we will begin by visualizing the number of publications per year. </p>
# <p>By looking at the number of published papers per year,  we can understand the extent of the machine learning 'revolution'! Typically, this significant increase in popularity is attributed to the large amounts of compute power, data and improvements in algorithms.</p>

# %%
# Group the papers by year
#print(papers)
groups = papers.groupby(by = ["year"])
#print(groups)
# Determine the size of each group
counts = groups['year'].count()
print(counts)
# Visualise the counts as a bar plot
import matplotlib.pyplot as plt 

counts.plot(kind = 'bar', title = "Number of papers published each year")
# Out:
# year
# 1987     90
# 1988     94
# 1989    101
# 1990    143
# 1991    144
# 1992    127
# 1993    158
# 1994    140
# 1995    152
# 1996    152
# 1997    150
# 1998    151
# 1999    150
# 2000    152
# 2001    197
# 2002    207
# 2003    198
# 2004    207
# 2005    207
# 2006    204
# 2007    217
# 2008    250
# 2009    262
# 2010    292
# 2011    306
# 2012    368
# 2013    360
# 2014    411
# 2015    403
# 2016    569
# 2017    679
# Name: year, dtype: int64

# %% [markdown]
# ## 4. Preprocessing the text data
# <p>Let's now analyze the titles of the different papers to identify machine learning trends. First, we will perform some simple preprocessing on the titles in order to make them more amenable for analysis. We will use a regular expression to remove any punctuation in the title. Then we will perform lowercasing. We'll then print the titles of the first rows before and after applying the modification.</p>

# %%
# Load the regular expression library
import re

# Print the titles of the first rows 
print(papers['title'].head())

# Remove punctuation
papers['title_processed'] = papers['title'].map(lambda x: re.sub('[,\.!?]', '', x))

# Convert the titles to lowercase
papers['title_processed'] = papers['title_processed'].str.lower() 

# Print the processed titles of the first rows 
print(papers['title_processed'].head())
# Out:
# 0    Self-Organization of Associative Database and ...
# 1    A Mean Field Theory of Layer IV of Visual Cort...
# 2    Storing Covariance by the Associative Long-Ter...
# 3    Bayesian Query Construction for Neural Network...
# 4    Neural Network Ensembles, Cross Validation, an...
# Name: title, dtype: object
# 0    self-organization of associative database and ...
# 1    a mean field theory of layer iv of visual cort...
# 2    storing covariance by the associative long-ter...
# 3    bayesian query construction for neural network...
# 4    neural network ensembles cross validation and ...
# Name: title_processed, dtype: object

# %% [markdown]
# ## 5.  A word cloud to visualize the preprocessed text data
# <p>In order to verify whether the preprocessing happened correctly, we can make a word cloud of the titles of the research papers. This will give us a visual representation of the most common words. Visualisation is key to understanding whether we are still on the right track! In addition, it allows us to verify whether we need additional preprocessing before further analyzing the text data.</p>
# <p>Python has a massive number of open libraries! Instead of trying to develop a method to create word clouds ourselves, we'll use Andreas Mueller's <a href="http://amueller.github.io/word_cloud/">wordcloud library</a>.</p>

# %%
# Import the wordcloud library
import numpy as np
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# Join the different processed titles together.
long_string = papers['title_processed'].to_string()
print(long_string)

# Create a WordCloud object
wordcloud = WordCloud()

# Generate a word cloud
wordcloud.generate(long_string)

# Visualize the word cloud
wordcloud.to_image()
# Out:
# 0       self-organization of associative database and ...
# 1       a mean field theory of layer iv of visual cort...
# 2       storing covariance by the associative long-ter...
# 3       bayesian query construction for neural network...
# 4       neural network ensembles cross validation and ...
# 5       using a neural net to instantiate a deformable...
# 6                plasticity-mediated competitive learning
# 7       iceg morphology classification using an analog...
# 8       real-time control of a tokamak plasma using ne...
# 9       pulsestream synapses with non-volatile analogu...
# 10                     learning to play the game of chess
# 11           multidimensional scaling and data clustering
# 12      an experimental comparison of recurrent neural...
# 13      training multilayer perceptrons with the exten...
# 14      interference in learning internal models of in...
# 15                active learning with statistical models
# 16      a rapid graph-based method for arbitrary trans...
# 17      ocular dominance and patterned lateral connect...
# 18      associative decorrelation dynamics: a theory o...
# 19      a connectionist technique for accelerated text...
# 20      connectionist speaker normalization with gener...
# 21      a critical comparison of models for orientatio...
# 22      generalization in reinforcement learning: safe...
# 23      a mixture model system for medical and machine...
# 24      an application of the principle of maximum inf...
# 25      a computational model of prefrontal cortex fun...
# 26           the gamma mlp for speech phoneme recognition
# 27      a multiscale attentional framework for relaxat...
# 28      correlated neuronal response: time scales and ...
# 29                         onset-based sound segmentation
# 30      a model of transparent motion and non-transpar...
# 31                          a model of auditory streaming
# 32      remap: recursive estimation and maximization o...
# 33      exponentially many local minima for single neu...
# 34      a practical monte carlo implementation of baye...
# 35      an adaptive network that learns sequences of t...
# 36      neuron-mos temporal winner search hardware for...
# 37      dynamics of attention as near saddle-node bifu...
# 38            vlsi model of primate visual smooth pursuit
# 39      gradient and hamiltonian dynamics applied to l...
# 40      is learning the n-th thing any easier than lea...
# 41      a dynamical model of context dependencies for ...
# 42      improved gaussian mixture density estimates us...
# 43      quadratic-type lyapunov functions for competit...
# 44      stable linear approximations to dynamic progra...
# 45      context-dependent classes in a hybrid recurren...
# 46            digital realisation of self-organising maps
# 47      empirical entropy manipulation for real-world ...
# 48        the geometry of eye rotations and listing's law
# 49         reinforcement learning by probability matching
# 50           neural control for nonlinear dynamic systems
# 51      learning with ensembles: how overfitting can b...
# 52      seemore: a view-based approach to 3-d object r...
# 53      analog vlsi processor implementing the continu...
# 54      selective attention for handwritten digit reco...
# 55                      gaussian processes for regression
# 56      modern analytic techniques to solve the dynami...
# 57      backpropagation and its application to handwri...
# 58                                       family discovery
# 59            neural networks with quadratic vc dimension
# 60                   learning the structure of similarity
# 61      reorganisation of somatosensory cortex after t...
# 62      implementation issues in the fourier transform...
# 63      adaptive retina with center-surround receptive...
# 64      forward-backward retraining of recurrent neura...
# 65      when is an integrate-and-fire neuron like a po...
# 66      from isolation to cooperation: an alternative ...
# 67                                boosting decision trees
# 68      constraints on adaptive networks for modeling ...
# 69      statistical theory of overtraining - is cross-...
# 70                      stable dynamic parameter adaption
# 71      universal approximation and learning of trajec...
# 72      learning fine motion by markov mixtures of exp...
# 73             estimating the bayes risk from sample data
# 74      a unified learning scheme: bayesian-kullback y...
# 75                on neural networks with minimal weights
# 76      spert-ii: a vector microprocessor system and i...
# 77      a neural network model of 3-d lightness percep...
# 78      how perception guides production in birdsong l...
# 79      neural network recognizer for hand-written zip...
# 80      a bound on the error of cross validation using...
# 81      a model of spatial representations in parietal...
# 82      dynamics of on-line gradient descent learning ...
# 83      improving elevator performance using reinforce...
# 84      visual gesture-based robot guidance with a mod...
# 85      improving committee diagnosis with resampling ...
# 86                            learning sparse perceptrons
# 87      a neural network autoassociator for induction ...
# 88      modeling interactions of the rat's place and h...
# 89      active gesture recognition using learned visua...
# 90      neural networks for model matching and percept...
# 91                symplectic nonlinear component analysis
# 92      using the future to "sort out" the present: ra...
# 93                  prediction of beta sheets in proteins
# 94                          unsupervised pixel-prediction
# 95      high-speed airborne particle monitoring using ...
# 96      high-performance job-shop scheduling with a ti...
# 97      examples of learning curves from a modified vc...
# 98      using feedforward neural networks to monitor a...
# 99      softassign versus softmax: benchmarks in combi...
# 100     beating a defender in robotic soccer: memory-b...
# 101     applications of error back-propagation to phon...
# 102        absence of cycles in symmetric neural networks
# 103     independent component analysis of electroencep...
# 104     clustering data through an analogy to the pott...
# 105     plasticity of center-surround opponent recepti...
# 106             worst-case loss bounds for single neurons
# 107     predictive q-routing: a memory-based reinforce...
# 108          using unlabeled data for supervised learning
# 109     discovering structure in continuous variables ...
# 110         adaptive mixture of probabilistic transducers
# 111     microelectronic implementations of connectioni...
# 112     adaptive neural networks using mos charge storage
# 113     tempering backpropagation networks: not all we...
# 114     finite state automata that recurrent cascade-c...
# 115     hierarchical recurrent neural networks for lon...
# 116                          optimizing cortical mappings
# 117     kodak lmagelink ocr alphanumeric handprint module
# 118     cholinergic suppression of transmission may al...
# 119     handwritten word recognition using contextual ...
# 120         human reading and the curse of dimensionality
# 121     sample complexity for learning recurrent perce...
# 122     generalization in reinforcement learning: succ...
# 123     dynamics of analog neural networks with time d...
# 124     fast learning by bounding likelihoods in sigmo...
# 125                                   learning model bias
# 126              generalized learning vector quantization
# 127     stock selection via nonlinear multi-factor models
# 128     a new learning algorithm for blind signal sepa...
# 129                             classifying facial action
# 130     parallel optimization of motion controllers vi...
# 131     a framework for non-rigid matching and corresp...
# 132     a smoothing regularizer for recurrent neural n...
# 133                                cricket wind detection
# 134           optimization principles for the neural code
# 135     optimal asset allocation using adaptive dynami...
# 136     recursive estimation of dynamic modular rbf ne...
# 137            silicon models for auditory scene analysis
# 138                  memory-based stochastic optimization
# 139     parallel analog vlsi architectures for computa...
# 140     recurrent neural networks for missing or async...
# 141     a realizable learning task which exhibits over...
# 142          modeling saccadic targeting in visual search
# 143     simulation of a thalamocortical circuit for co...
# 144     use of multi-layered networks for coding speec...
# 145       some results on convergent unlearning algorithm
# 146     discriminant adaptive nearest neighbor classif...
# 147     em optimization of latent-variable density models
# 148                  stable fitted reinforcement learning
# 149     competence acquisition in an autonomous mobile...
# 150                  information through a spiking neuron
# 151                                the capacity of a bump
# 152     a dynamical systems approach for a learnable a...
# 153     rapid quality estimation of neural network inp...
# 154     implications of recursive distributed represen...
# 155             active learning in multilayer perceptrons
# 156           investment learning with hierarchical psoms
# 157              explorations with the dynamic wave model
# 158           improving policies without measuring merits
# 159                        factorial hidden markov models
# 160     a predictive switching model of cerebellar mov...
# 161     the role of activity in synaptic competition a...
# 162         geometry of early stopping in linear networks
# 163     strong unimodality and exact learning of const...
# 164     laterally interconnected self-organizing maps ...
# 165     heterogeneous neural networks for adaptive beh...
# 166     primitive manipulation learning with connectio...
# 167     learning long-term dependencies is not as diff...
# 168     extracting tree-structured representations of ...
# 169     does the wake-sleep algorithm produce good den...
# 170     control of selective visual attention: modelin...
# 171     exploiting tractable substructures in intracta...
# 172     adaptive back-propagation in on-line learning ...
# 173     temporal coding in the sub-millisecond range: ...
# 174     on the computational power of noisy spiking ne...
# 175     a novel channel selection system in cochlear i...
# 176     convergence and pattern-stabilization in the b...
# 177                          harmony networks do not work
# 178     an information-theoretic learning algorithm fo...
# 179     experiments with neural networks for real time...
# 180     generalisation of a class of continuous neural...
# 181     learning to predict visibility and invisibilit...
# 182     constructive algorithms for hierarchical mixtu...
# 183                   model matching and sfmd computation
# 184              bayesian methods for mixtures of experts
# 185                 human face detection in visual scenes
# 186     temporal difference learning in continuous tim...
# 187     a neural network classifier for the i100 ocr chip
# 188     using pairs of data-points to define splits fo...
# 189     stochastic hillclimbing as a baseline method f...
# 190     improved silicon cochlea using compatible late...
# 191     pruning with generalization based weight salie...
# 192     generating accurate and diverse members of a n...
# 193       statistical mechanics of the mixture of experts
# 194     microscopic equations in rough energy landscap...
# 195     an architectural mechanism for direction-tuned...
# 196     maximum likelihood blind source separation: a ...
# 197        learning by choice of internal representations
# 198     representing face images for emotion classific...
# 199                                    early brain damage
# 200                 balancing between bagging and bumping
# 201     adaptive on-line learning in changing environm...
# 202     radial basis function networks and complexity ...
# 203     learning decision theoretic utilities through ...
# 204     text-based information retrieval using exponen...
# 205     support vector method for function approximati...
# 206     spatiotemporal coupling and scaling of natural...
# 207     second-order learning algorithm with squared p...
# 208     skeletonization: a technique for trimming the ...
# 209     source separation and density estimation by fa...
# 210     regression with input-dependent noise: a bayes...
# 211     bangs clicks snaps thuds and whacks: an archit...
# 212     a new approach to hybrid hmm/ann speech recogn...
# 213                     an apobayesian relative of winnow
# 214     hebb learning of features based on their infor...
# 215     competition among networks improves committee ...
# 216                      computing with infinite networks
# 217     arc-lh: a new adaptive resampling algorithm fo...
# 218     neural network models of chemotaxis in the nem...
# 219     using neural networks to improve cochlear impl...
# 220     a model of neural oscillator for a unified sub...
# 221        visual cortex circuitry and orientation tuning
# 222     combining neural network regression estimates ...
# 223     dual kalman filtering methods for nonlinear pr...
# 224      time series prediction using mixtures of experts
# 225     for valid generalization the size of the weigh...
# 226        an adaptive wta using floating gate technology
# 227     a micropower analog vlsi hmm state decoder for...
# 228     gtm: a principled alternative to the self-orga...
# 229     a mixture of experts classifier with learning ...
# 230     complex-cell responses derived from center-sur...
# 231     learning the solution to the aperture problem ...
# 232     self-organizing and adaptive algorithms for ge...
# 233     learning bayesian belief networks with neural ...
# 234     selective integration: a model for disparity e...
# 235     on the effect of analog noise in discrete-time...
# 236     a convergence proof for the softassign quadrat...
# 237            lstm can solve hard long time lag problems
# 238     reinforcement learning for dynamic channel all...
# 239        clustering sequences with hidden markov models
# 240     on a modification to the mean field em algorit...
# 241     mlp can provably generalize much better than v...
# 242     gemini: gradient estimation through matrix inv...
# 243                    the generalisation cost of ramnets
# 244               multi-task learning for stock selection
# 245     extraction of temporal features in the electro...
# 246     learning appearance based models: mixtures of ...
# 247                           learning from demonstration
# 248                                  dynamics of training
# 249     viewpoint invariant face recognition using ind...
# 250     using curvature information for fast stochasti...
# 251     efficient nonlinear control with actor-tutor a...
# 252     multidimensional triangulation and interpolati...
# 253            linear learning: landscapes and algorithms
# 254     local bandit approximation for optimal learnin...
# 255     promoting poor features to supervisors: some i...
# 256     gaussian processes for bayesian classification...
# 257     fast network pruning and feature extraction by...
# 258     a constructive learning algorithm for discrimi...
# 259     blind separation of delayed and convolved sources
# 260              neural models for part-whole hierarchies
# 261                    support vector regression machines
# 262     multilayer neural networks: one or two hidden ...
# 263     models of ocular dominance column formation: a...
# 264     predicting lifetimes in dynamically allocated ...
# 265     ordered classes and incomplete examples in cla...
# 266      unsupervised learning by convex and conic coding
# 267     learning with noise and regularizers in multil...
# 268          a neural model of visual contour integration
# 269     sequential tracking in pricing financial optio...
# 270     genetic algorithms and explicit search statistics
# 271     neural learning in structured parameter spaces...
# 272     an analog implementation of the constant avera...
# 273       training a 3-node neural network is np-complete
# 274     effective training of a neural network charact...
# 275     multi-effect decompositions for financial data...
# 276     a comparison between neural networks and other...
# 277     improving the accuracy and speed of support ve...
# 278     the effect of correlated input data on the dyn...
# 279     a model of recurrent interactions in primary v...
# 280     the learning dynamcis of a universal approximator
# 281     removing noise in on-line search using adaptiv...
# 282      a constructive rbf network for writer adaptation
# 283     are hopfield networks faster than conventional...
# 284             computer modeling of associative learning
# 285                   clustering via concave minimization
# 286     continuous sigmoidal belief networks trained u...
# 287       temporal low-order statistics of natural sounds
# 288     training algorithms for hidden markov models u...
# 289                          hidden markov decision trees
# 290     a silicon model of amplitude modulation detect...
# 291     learning temporally persistent hierarchical re...
# 292      adaptive access control applied to ethernet data
# 293     a mean field algorithm for bayes learning in l...
# 294     analysis of temporal-diffference learning with...
# 295                  optimization by mean field annealing
# 296                                    monotonicity hints
# 297     online learning from finite training sets: an ...
# 298     bayesian model comparison by monte carlo chaining
# 299     multi-grid methods for reinforcement learning ...
# 300     learning exact patterns of quasi-synchronizati...
# 301     representation and induction of finite state m...
# 302     neural network modeling of speech and music si...
# 303                a hierarchical model of visual rivalry
# 304     reinforcement learning for mixed open-loop and...
# 305     adaptively growing hierarchical mixtures of ex...
# 306       electronic receptors for tactile/haptic sensing
# 307           ensemble methods for phoneme classification
# 308     dynamically adaptable cmos winner-take-all neu...
# 309     unification of information maximization and mi...
# 310      a variational principle for model-based morphing
# 311     analytical mean squared error curves in tempor...
# 312     spectroscopic detection of cervical pre-cancer...
# 313     analog vlsi circuits for attention-based visua...
# 314     vlsi implementation of cortical visual motion ...
# 315              minimizing statistical bias with queries
# 316     the condensation algorithm - conditional densi...
# 317     scaling and generalization in neural networks:...
# 318                          separating style and content
# 319            contour organisation with the em algorithm
# 320                                why did td-gammon work
# 321     bayesian unsupervised learning of higher order...
# 322     dynamic features for visual speechreading: a s...
# 323     limitations of self-organizing maps for vector...
# 324     3d object recognition: a model of view-tuned n...
# 325     approximate solutions to optimal stopping prob...
# 326                      488 solutions to the xor problem
# 327     the neurothermostat: predictive optimal contro...
# 328      temporal patterns of activity in neural networks
# 329     statistical prediction with kanerva's sparse d...
# 330     reconstructing stimulus velocity from neuronal...
# 331     on-line policy improvement using monte-carlo s...
# 332     size of multilayer networks for exact learning...
# 333     spatial decorrelation in orientation tuned cor...
# 334        rapid visual processing using spike asynchrony
# 335         practical confidence and prediction intervals
# 336     noisy spiking neurons with temporal coding hav...
# 337                         softening discrete relaxation
# 338     interpreting images by propagating bayesian be...
# 339     modeling small oscillating biological networks...
# 340     salient contour extraction by temporal binding...
# 341               consistent classification firm and soft
# 342     statistically efficient estimations using cort...
# 343     interpolating earth-science data using rbf net...
# 344     smoothing regularizers for projective basis fu...
# 345     one-unit learning rules for independent compon...
# 346     recursive algorithms for approximating probabi...
# 347     exploiting model uncertainty estimates for saf...
# 348                 triangulation by continuous embedding
# 349     cholinergic modulation preserves spike timing ...
# 350          theory of self-organization of cortical maps
# 351     an orientation selective neural network for pa...
# 352     edges are the 'independent components' of natu...
# 353          a spike based learning neuron in analog vlsi
# 354     neuroscale: novel topographic feature extracti...
# 355      probabilistic interpretation of population codes
# 356                      combinations of weak classifiers
# 357     estimating equivalent kernels for neural netwo...
# 358     compositionality mdl priors and object recogni...
# 359     mimic: finding optima by estimating probabilit...
# 360     artex: a self-organizing architecture for clas...
# 361     a back-propagation algorithm with optimal use ...
# 362     orientation contrast sensitivity from long-ran...
# 363     recovering perspective pose with a dual step e...
# 364         mapping a manifold of perceptual observations
# 365     the efficiency and the robustness of natural g...
# 366                     features as sufficient statistics
# 367     training methods for adaptive boosting of neur...
# 368     minimax and hamiltonian dynamics of excitatory...
# 369     analog vlsi model of intersegmental coordinati...
# 370     dynamic stochastic synapses as computational u...
# 371     modeling acoustic correlations by factor analysis
# 372     efficient parallel learning algorithms for neu...
# 373     generalization in decision trees and dnf: does...
# 374     nonlinear markov networks for continuous varia...
# 375     multiplicative updating rule for blind separat...
# 376     extended ica removes artifacts from electroenc...
# 377     analytical study of the interplay between arch...
# 378                      multi-modular associative memory
# 379            a framework for multiple-instance learning
# 380               incorporating test inputs into learning
# 381     a solution for missing data in recurrent neura...
# 382               learning to schedule straight-line code
# 383     a connectionist expert system that actually works
# 384     analysis of drifting dynamics with neural netw...
# 385          2d observers for human 3d object recognition
# 386     a simple and fast neural network approach to s...
# 387                            stacked density estimation
# 388     phase transitions and the perceptual organizat...
# 389     a neural network model of naive preference and...
# 390     on parallel versus serial processing: a comput...
# 391     the canonical distortion measure in feature sp...
# 392                                    monotonic networks
# 393     data-dependent structural risk minimization fo...
# 394                             automatic local annealing
# 395     silicon retina with adaptive filtering properties
# 396     recurrent neural networks can learn to impleme...
# 397     multi-time models for temporally abstract plan...
# 398                                active data clustering
# 399     an analog vlsi neural network for phase-based ...
# 400     toward a single-cell account for binocular dis...
# 401     blind separation of radio signals in fading ch...
# 402     an analog vlsi model of the fly elementary mot...
# 403                      computing with action potentials
# 404     learning continuous attractors in recurrent ne...
# 405     an electronic photoreceptor sensitive to small...
# 406     melonet i: neural nets for inventing baroque-s...
# 407            detection of first and second order motion
# 408     from regularization operators to support vecto...
# 409               globally optimal on-line learning rules
# 410     just one view: invariances in inferotemporal c...
# 411                   classification by pairwise coupling
# 412        agnostic classification of markovian sequences
# 413       bidirectional retrieval from associative memory
# 414     using expectation to guide processing: a study...
# 415              shared context probabilistic transducers
# 416     modeling the olfactory bulb - coupled nonlinea...
# 417     estimating dependency structure as a hidden va...
# 418     hippocampal model of rat spatial abilities usi...
# 419     reinforcement learning for call admission cont...
# 420         the asymptotic convergence-rate of q-learning
# 421     reinforcement learning with hierarchies of mac...
# 422     the observer-observation dilemma in neuro-fore...
# 423     automated aircraft recovery via reinforcement ...
# 424                        local dimensionality reduction
# 425          on efficient heuristic ranking of hypotheses
# 426     serial order in reading aloud: connectionist m...
# 427     an optimality principle for unsupervised learning
# 428     on-line learning from finite training sets in ...
# 429     effects of spike timing underlying binocular i...
# 430     approximating posterior distributions in belie...
# 431      comparison of human and machine word recognition
# 432     combining classifiers using correspondence ana...
# 433     a 1 000-neuron system with one million 7-bit p...
# 434                       multiple threshold neural logic
# 435     function approximation with the sweeping hinge...
# 436                        em algorithms for pca and spca
# 437     task and spatial frequency effects on face spe...
# 438     encoding geometric invariances in higher-order...
# 439            associative learning via inhibitory search
# 440     synchronized auditory and cognitive 40 hz atte...
# 441     coding of naturalistic stimuli by auditory mid...
# 442                   the rectified gaussian distribution
# 443     modeling complex cells in an awake macaque dur...
# 444     reinforcement learning for continuous stochast...
# 445     hybrid nn/hmm-based speech recognition with a ...
# 446      bayesian robustification for audio visual fusion
# 447     use of a multi-layer perceptron to predict mal...
# 448     new approximations of differential entropy for...
# 449                      generalized prioritized sweeping
# 450     speech production using a neural network with ...
# 451     a mathematical model of axon guidance by diffu...
# 452     instabilities in eye movement control: a model...
# 453     boltzmann machine learning using mean field th...
# 454     selecting weighting factors in logarithmic opi...
# 455     visual navigation in a robot using zig-zag beh...
# 456             a hippocampal model of recognition memory
# 457     correlates of attention in a model of dynamic ...
# 458     s-map: a network with a simple self-organizati...
# 459     an incremental nearest neighbor algorithm with...
# 460                 competitive on-line linear regression
# 461     connectionist learning of expert preferences b...
# 462     how to dynamically merge markov decision proce...
# 463                  bayesian model of surface perception
# 464     an application of reversible-jump mcmc to mult...
# 465                    gradients for retinotectal mapping
# 466     learning nonlinear overcomplete representation...
# 467     experiences with bayesian learning in a real w...
# 468     rcc cannot compute certain fsa even with arbit...
# 469     enhancing q-learning for optimal asset allocation
# 470     modelling seasonality and trends in daily rain...
# 471     temporal representations in a connectionist sp...
# 472     perturbative m-sequences for auditory systems ...
# 473                              learning to order things
# 474     the storage capacity of a fully-connected comm...
# 475     a generic approach for identification of event...
# 476     hybrid reinforcement learning and its applicat...
# 477     incorporating contextual information in white ...
# 478     ensemble and modular approaches for face detec...
# 479                  wavelet models for video time-series
# 480     learning path distributions using nonequilibri...
# 481       neural basis of object-centered representations
# 482     a passive shared element analog electrical coc...
# 483                   two approaches to optimal annealing
# 484     on the infeasibility of training neural networ...
# 485     using helmholtz machines to analyze multi-chan...
# 486     an annealed self-organizing map for source cha...
# 487     regression with input-dependent noise: a gauss...
# 488             structure driven image database retrieval
# 489             factorizing multivariate function classes
# 490     an improved policy iteration algorithm for par...
# 491                    adaptation in speech motor control
# 492     a bifurcation theory approach to the programmi...
# 493     a non-parametric multi-scale statistical model...
# 494          radial basis functions: a bayesian treatment
# 495     asymptotic theory for regularization: one-dime...
# 496     graph matching with hierarchical discrete rela...
# 497     a general purpose image processing chip: orien...
# 498     on the separation of signals from neighboring ...
# 499             prior knowledge in support vector kernels
# 500     receptive field formation in natural scene env...
# 501              intrusion detection with neural networks
# 502     performance of synthetic neural network classi...
# 503          self-similarity properties of natural images
# 504                   refractoriness and neural precision
# 505     characterizing neurons in the primary auditory...
# 506                    statistical models of conditioning
# 507      regularisation in sequential learning algorithms
# 508     adaptive choice of grid and time in reinforcem...
# 509     independent component analysis for identificat...
# 510     a revolution: belief propagation in graphs wit...
# 511     learning human-like knowledge by singular valu...
# 512     a superadditive-impairment theory of optic aph...
# 513          a network for image segmentation using color
# 514                     bach in a box - real-time harmony
# 515                    a model of early visual processing
# 516     hierarchical non-linear factor analysis and to...
# 517     linear concepts and hidden variables: an empir...
# 518     multiresolution tangent distance for affine-in...
# 519     structural risk minimization for nonparametric...
# 520      nonparametric model-based reinforcement learning
# 521     synaptic transmission: an information-theoreti...
# 522     relative loss bounds for multidimensional regr...
# 523     unsupervised on-line learning of decision tree...
# 524     adaptive neural net preprocessing for signal d...
# 525            ensemble learning for multi-layer networks
# 526               the error coding and substitution pacts
# 527     a principle for unsupervised hierarchical deco...
# 528     the bias-variance tradeoff and the randomized ...
# 529                    graph matching for shape retrieval
# 530     dynamically adapting kernels in support vector...
# 531     evidence for a forward dynamics model in human...
# 532     a reinforcement learning algorithm in partiall...
# 533                a model for associative multiplication
# 534               a neuromorphic monaural sound localizer
# 535     self organizing neural networks for the identi...
# 536     very fast em-based mixture model clustering us...
# 537           kernel pca and de-noising in feature spaces
# 538     viewing classifier systems as model free learn...
# 539     multi-electrode spike sorting by clustering tr...
# 540     where does the population vector of motor cort...
# 541     a high performance k-nn classifier using a bin...
# 542     coordinate transformation learning of hand pos...
# 543     finite-dimensional approximation of gaussian p...
# 544     making templates rotationally invariant an app...
# 545     vlsi implementation of motion centroid localiz...
# 546     correlational strength and computational algeb...
# 547     an information theoretic approach to rule-base...
# 548     outcomes of the equivalence of adaptive ridge ...
# 549                learning curves for gaussian processes
# 550     adding constrained discontinuities to gaussian...
# 551                             learning from dyadic data
# 552     example-based image synthesis of articulated f...
# 553     call-based fraud detection in mobile communica...
# 554     applications of multi-resolution neural networ...
# 555     lazy learning meets the recursive least square...
# 556     markov processes on curves for automatic speec...
# 557     experimental results on learning stochastic me...
# 558           winner-take-all networks of o(n) complexity
# 559     the effect of correlations on the fisher infor...
# 560                         learning multi-class dynamics
# 561     replicator equations maximal cliques and graph...
# 562     convergence rates of algorithms for visual sea...
# 563     coding time-varying signals using sparse shift...
# 564     almost linear vc dimension bounds for piecewis...
# 565                     probabilistic image sensor fusion
# 566     on the optimality of incremental neural networ...
# 567     contrast adaptation in simple cells by changin...
# 568     controlling the complexity of hmm systems by r...
# 569     simulation and measurement of the electric fie...
# 570     exploiting generative models in discriminative...
# 571                     smem algorithm for mixture models
# 572         an entropic estimator for structure discovery
# 573     optimizing classifers for imbalanced training ...
# 574     batch and on-line parameter estimation of gaus...
# 575     recurrent cortical amplification produces comp...
# 576     facial memory is kernel density estimation (al...
# 577     orientation scale and discontinuity as emergen...
# 578     stationarity and stability of autoregressive n...
# 579     range image restoration using mean field annea...
# 580     a precise characterization of the class of lan...
# 581     finite-sample convergence rates for q-learning...
# 582     mean field methods for classification with gau...
# 583     modeling surround suppression in v1 neurons wi...
# 584     analog vlsi cellular implementation of the bou...
# 585                                    dts: dynamic trees
# 586     divisive normalization line attractor networks...
# 587     maximum conditional likelihood via bound maxim...
# 588             robot docking using mixtures of gaussians
# 589     fisher scoring and a mixture of modes approach...
# 590              what size net gives valid generalization
# 591     general-purpose localization of textured image...
# 592     active noise canceling using analog neuro-chip...
# 593           bayesian modeling of human concept learning
# 594                          learning mixture hierarchies
# 595     exploratory data analysis using radial basis f...
# 596     independent component analysis of intracellula...
# 597     vertex identification in high energy physics e...
# 598     attentional modulation of human pattern discri...
# 599            familiarity discrimination of radar pulses
# 600                                          bayesian pca
# 601         an analog self-organizing neural network chip
# 602     robust efficient globally-optimized reinforcem...
# 603                    reinforcement learning for trading
# 604                           visualizing group structure
# 605     direct optimization of margins improves genera...
# 606     neuronal regulation implements efficient synap...
# 607     computation of smooth optical flow in a feedba...
# 608     distributional population codes and multiple m...
# 609     scheduling straight-line code using reinforcem...
# 610     a micropower cmos adaptive amplitude and shift...
# 611     computational differences between asymmetrical...
# 612     comparing biases for minimal network construct...
# 613     graphical models for recognizing human interac...
# 614     probabilistic visualisation of high-dimensiona...
# 615     fast neural network emulation of dynamical sys...
# 616     shrinking the tube: a new support vector regre...
# 617     inference in multilayer networks via large dev...
# 618     barycentric interpolators for continuous space...
# 619     probabilistic modeling for face orientation di...
# 620     blind separation of filtered sources using sta...
# 621     discontinuous recall transitions induced by co...
# 622                     on the k-winners-take-all network
# 623                                     the belief in tap
# 624             classification on pairwise proximity data
# 625            information maximization in single neurons
# 626     learning instance-independent value functions ...
# 627     analyzing and visualizing single-trial event-r...
# 628     semiparametric support vector and linear progr...
# 629     gradient descent for general reinforcement lea...
# 630     using analytic qp and sparseness to speed trai...
# 631     dynamics of supervised learning with restricte...
# 632     discovering hidden features with gaussian proc...
# 633     neural networks that learn to discriminate sim...
# 634     learning a continuous hidden variable model fo...
# 635                   classification in non-metric spaces
# 636               semi-supervised support vector machines
# 637                 risk sensitive reinforcement learning
# 638     learning lie groups for invariant visual perce...
# 639     multiple paired forward-inverse models for hum...
# 640      learning macro-actions in reinforcement learning
# 641     phase diagram and storage capacity of sequence...
# 642                approximate learning of dynamic models
# 643     perceiving without learning: from spirals to i...
# 644        performance of a stochastic learning microchip
# 645                bayesian modeling of facial similarity
# 646     using collective intelligence to route interne...
# 647     unsupervised classification with non-gaussian ...
# 648        a randomized algorithm for pairwise clustering
# 649     learning nonlinear dynamical systems using an ...
# 650                   learning to find pictures of people
# 651     restructuring sparse high dimensional data for...
# 652     global optimisation of neural network models v...
# 653     optimizing admission control while ensuring qu...
# 654     network generality training required and preci...
# 655     analyzing the energy landscapes of distributed...
# 656     non-linear pi control inspired by biological c...
# 657     the role of lateral cortical competition in oc...
# 658     boxlets: a fast convolution algorithm for sign...
# 659     the effect of eligibility traces on finding op...
# 660                  a theory of mean field approximation
# 661     tight bounds for the vc-dimension of piecewise...
# 662     on-line learning with restricted training sets...
# 663     improved switching among temporally abstract a...
# 664     exploring unknown environments with real-time ...
# 665     support vector machines applied to face recogn...
# 666     neural approach for tv image compression using...
# 667                  linear hinge loss and average margin
# 668     synergy and redundancy among brain cells of be...
# 669     sparse code shrinkage: denoising by nonlinear ...
# 670     an integrated vision sensor for the computatio...
# 671     reinforcement learning based on on-line em alg...
# 672                                 regularizing adaboost
# 673     efficient bayesian parameter estimation in lar...
# 674     tractable variational structures for approxima...
# 675     a v1 model of pop out and asymmetty in visual ...
# 676     source separation as a by-product of regulariz...
# 677       mapping classifier systems into neural networks
# 678     temporally asymmetric hebbian learning spike l...
# 679     optimizing correlation algorithms for hardware...
# 680     general bounds on bayes errors for regression ...
# 681                basis selection for wavelet regression
# 682                neural networks for density estimation
# 683     unsupervised and supervised clustering: the mu...
# 684     a phase space approach to minimax entropy lear...
# 685     a polygonal line algorithm for constructing pr...
# 686                  utilizing lime: asynchronous binding
# 687               learning to estimate scenes from images
# 688     links between markov models and multilayer per...
# 689     mechanisms of generalization in perceptual lea...
# 690     learning a hierarchical belief network of inde...
# 691               convergence of the wake-sleep algorithm
# 692     signal detection in noisy weakly-active dendrites
# 693     maximum-likelihood continuity mapping (malcom)...
# 694     spike-based compared to rate-based hebbian lea...
# 695     neural computation with winner-take-all as the...
# 696                bayesian modelling of fmri lime series
# 697     an oculo-motor system with multi-chip neuromor...
# 698     algorithms for independent components analysis...
# 699     dynamic non-local role bindings and inferencin...
# 700     approximate inference a lgorithms for two-laye...
# 701     correctness of belief propagation in gaussian ...
# 702                 robust learning of chaotic attractors
# 703     gaussian fields for approximate inference in l...
# 704     generalized model selection for unsupervised l...
# 705     on input selection with reversible jump markov...
# 706     memory capacity of linear vs nonlinear models ...
# 707     an information-theoretic framework for underst...
# 708     online independent component analysis with loc...
# 709     local probability propagation for factor analysis
# 710     a massively parallel self-tuning context-free ...
# 711     a mcmc approach to hierarchical mixture modelling
# 712                  agglomerative information bottleneck
# 713     support vector method for multivariate density...
# 714     semiparametric approach to multichannel blind ...
# 715     learning the similarity of documents: an infor...
# 716     search for information bearing components in s...
# 717     resonance in a stochastic neuron model with de...
# 718     information capacity and robustness of stochas...
# 719     spike-based learning rules and stabilization o...
# 720     boosting with multi-way branching in decision ...
# 721     a programmable analog neural computer and simu...
# 722     reconstruction of sequential data with probabi...
# 723                inference for the generalization error
# 724     application of blind separation of sources to ...
# 725           model selection for support vector machines
# 726     approximate planning in large pomdps via reusa...
# 727     an environment model for nonstationary reinfor...
# 728              rules and similarity in concept learning
# 729     reinforcement learning using approximate belie...
# 730     learning sparse codes with a mixture-of-gaussi...
# 731     an oscillatory correlation frame work for comp...
# 732                                   neural architecture
# 733     emergence of topography and complex cell prope...
# 734     training data selection for optimal generaliza...
# 735     variational inference for bayesian mixtures of...
# 736                            mixture density estimation
# 737     model selection in clustering by uniform conve...
# 738     image recognition in context: application to m...
# 739     recurrent cortical competition: strengthen or ...
# 740      the entropy regularization information criterion
# 741     information factorization in connectionist mod...
# 742     modeling high-dimensional discrete data with m...
# 743     neural control of sensory acquisition: the ves...
# 744     broadband direction-of-arrival estimation base...
# 745      dual estimation and the unscented transformation
# 746     independent factor analysis with temporally st...
# 747     recognizing evoked potentials in a virtual env...
# 748     bayesian network induction via local neighborh...
# 749     audio vision: using audio-visual synchrony to ...
# 750       a geometric interpretation of v-svm classifiers
# 751     graded grammaticality in prediction fractal ma...
# 752     some theoretical results concerning the conver...
# 753     an analog vlsi chip for thin-plate surface int...
# 754              bifurcation analysis of a silicon neuron
# 755                            greedy importance sampling
# 756     lower bounds on the complexity of approximatin...
# 757     dynamics of supervised learning with restricte...
# 758     efficient approaches to gaussian process class...
# 759             a generative model for attractor dynamics
# 760     robust recognition of noisy and superimposed p...
# 761                statistical dynamics of batch learning
# 762     bayesian reconstruction of 3d human motion fro...
# 763     transductive inference for estimating values o...
# 764              learning a color algorithm from examples
# 765                                song learning in birds
# 766     regular and irregular gallager-zype error-corr...
# 767     differentiating functions of the jacobian with...
# 768     distributed synchrony of spiking neurons in a ...
# 769     constructing heterogeneous committees using in...
# 770     a recurrent model of the interaction between p...
# 771     from coexpression to coregulation: an approach...
# 772     an meg study of response latency and variabili...
# 773     the parallel problems server: an interactive t...
# 774                 bayesian averaging is well-temperated
# 775     neuronal maps for sensory-motor control in the...
# 776                              learning to parse images
# 777     probabilistic methods for support vector machines
# 778                                 bayesian transduction
# 779     policy gradient methods for reinforcement lear...
# 780                           unmixing hyperspectral data
# 781     invariant feature extraction and classificatio...
# 782         bayesian map learning in dynamic environments
# 783     an improved decomposition algorithm for regres...
# 784     a multi-class linear learning algorithm relate...
# 785                          the relevance vector machine
# 786     a low-power cmos circuit which emulates tempor...
# 787     a neuromorphic vlsi system for modeling the ne...
# 788     v-arc: ensemble learning in the presence of ou...
# 789     bayesian model selection for support vector ma...
# 790           support vector method for novelty detection
# 791                            spiking boltzmann machines
# 792     a winner-take-all circuit with controllable so...
# 793     a variational baysian framework for graphical ...
# 794           the relaxed online maximum margin algorithm
# 795                      wiring optimization in the brain
# 796     topographic transformation as a discrete laten...
# 797     using backpropagation with temporal windows to...
# 798     perceptual organization based on temporal dyna...
# 799             spectral cues in human sound localization
# 800          optimal sizes of dendritic and axonal arbors
# 801                        maximum entropy discrimination
# 802       neural system model of human sound localization
# 803                        uniqueness of the svm solution
# 804     nonlinear discriminant analysis using kernel f...
# 805                                    potential boosters
# 806                      constrained hidden markov models
# 807     algebraic analysis for non-regular learning ma...
# 808     speech recognition: statistical and neural inf...
# 809     low power wireless communication via reinforce...
# 810      robust full bayesian methods for neural networks
# 811               managing uncertainty in cue combination
# 812                     the nonnegative boltzmann machine
# 813     kirchoff law markov fields for analog circuit ...
# 814                   the infinite gaussian mixture model
# 815     can vi mechanisms account for figure-ground an...
# 816                            a snow-based face detector
# 817                  policy search via density estimation
# 818              churn reduction in the wireless industry
# 819         fast learning in multi-resolution hierarchies
# 820     scale mixtures of gaussians and the statistics...
# 821         a neurodynamical approach to visual attention
# 822      population decoding based on an unfaithful model
# 823     an analysis of turbo decoding with gaussian de...
# 824     learning factored representations for partiall...
# 825     optimal kernel shapes for local linear regression
# 826     manifold stochastic dynamics for bayesian lear...
# ...
# 6967    an optimization method of layered neural netwo...
# 6968        recovering a feed-forward net from its output
# 6969    optimal brain surgeon: extensions and performa...
# 6970    probabilistic characterization of neural model...
# 6971    mixtures of controllers for jump linear and no...
# 6972             inverse dynamics of speech motor control
# 6973    dual mechanisms for neural binding and segment...
# 6974     neural network methods for optimization problems
# 6975              fast pruning using principal components
# 6976    wattle: a trainable gain analogue vlsi neural ...
# 6977    lower boundaries of motoneuron desynchronizati...
# 6978    fool's gold: extracting finite state machines ...
# 6979    neural network definitions of highly predictab...
# 6980    tonal music as a componential code: learning t...
# 6981    a dynamical approach to temporal pattern proce...
# 6982    processing of visual and auditory space and it...
# 6983                 hidden markov models for human genes
# 6984                      cross-validation estimates imse
# 6985    segmental neural net optimization for continuo...
# 6986    convergence of stochastic iterative dynamic pr...
# 6987    neural network exploration using optimal exper...
# 6988    odor processing in the bee: a preliminary stud...
# 6989    supervised learning from incomplete data via a...
# 6990    dopaminergic neuromodulation brings a dynamica...
# 6991    signature verification using a "siamese" time ...
# 6992    the performance of convex set projection based...
# 6993    packet routing in dynamically changing network...
# 6994                         resolving motion ambiguities
# 6995      optimal stochastic search and adaptive momentum
# 6996    convergence of indirect adaptive asynchronous ...
# 6997    gds: gradient descent generation of symbolic c...
# 6998    coupled dynamics of fast neurons and slow inte...
# 6999          an analog vlsi saccadic eye movement system
# 7000    bayesian modeling and classification of neural...
# 7001    a learning analog neural network chip with con...
# 7002      address block location with a neural net system
# 7003            learning representations by recirculation
# 7004           dynamic modulation of neurons and networks
# 7005    a comparison of dynamic reposing and tangent d...
# 7006    optimal unsupervised motor learning predicts t...
# 7007    a hodgkin-huxley type neuron model that learns...
# 7008    learning mackey-glass from 25 examples plus or...
# 7009        solvable models of artificial neural networks
# 7010    computational elements of the adaptive control...
# 7011    using local trajectory optimizers to speed up ...
# 7012        assessing the quality of learned local models
# 7013    learning in networks of nondeterministic adapt...
# 7014    a connectionist model of the owl's sound local...
# 7015     supervised learning with growing cell structures
# 7016    figure of merit training for detection and spo...
# 7017           directional hearing by the mauthner system
# 7018    recognition-based segmentation of on-line curs...
# 7019    analysis of short term memories for neural net...
# 7020    robust parameter estimation and model selectio...
# 7021    learning in computer vision and image understa...
# 7022    autoencoders minimum description length and he...
# 7023    catastrophic interference in connectionist net...
# 7024       the sigmoid nonlinearity in prepyriform cortex
# 7025    stochastic learning networks and their electro...
# 7026    foraging in an uncertain environment using pre...
# 7027      use of bad training data for better predictions
# 7028    constructive learning using internal represent...
# 7029    learning curves: asymptotic values and rate of...
# 7030    asynchronous dynamics of continuous time neura...
# 7031    probabilistic anomaly detection in dynamic sys...
# 7032             observability of neural network behavior
# 7033    memory-based methods for regression and classi...
# 7034         training neural networks with deficient data
# 7035                           bayesian self-organization
# 7036    invariant object recognition using a distribut...
# 7037    a hybrid radial basis function neurocomputer a...
# 7038    generalization error and the expected network ...
# 7039                   analyzing cross-connected networks
# 7040    functional models of selective attention and c...
# 7041     surface learning with applications to lipreading
# 7042    hoo optimality criteria for lms and backpropag...
# 7043    optimal stopping and effective machine complex...
# 7044    grammatical inference by attentional control o...
# 7045    adaptive knot placement for nonparametric regr...
# 7046    globally trained handwritten word recognizer u...
# 7047    simulations suggest information processing rol...
# 7048    temporal difference learning of position evalu...
# 7049    backpropagation convergence via deterministic ...
# 7050    bounds on the complexity of recurrent neural n...
# 7051    a comparative study of a modified bumptree neu...
# 7052    combined neural networks for time series analysis
# 7053                  fast non-linear dimension reduction
# 7054                             decoding cursive scripts
# 7055     connectionist models for auditory scene analysis
# 7056    connectionist modeling and parallel architectures
# 7057    neurobiology psychophysics and computational m...
# 7058    analysis and comparison of different learning ...
# 7059    a computational model for cursive handwriting ...
# 7060          learning classification with unlabeled data
# 7061    classifying hand gestures with a view-based di...
# 7062               backpropagation without multiplication
# 7063    event-driven simulation of networks of spiking...
# 7064    statistics of natural images: scaling in the w...
# 7065    when will a genetic algorithm outperform hill ...
# 7066    agnostic pac-learning of functions on analog n...
# 7067    clustering with a domain-specific distance mea...
# 7068    discontinuous generalization in large committe...
# 7069            presynaptic neural information processing
# 7070    learning in compositional hierarchies: inducin...
# 7071    hoeffding races: accelerating model selection ...
# 7072    a network mechanism for the determination of s...
# 7073     robust reinforcement learning in motion planning
# 7074    complexity issues in neural computation and le...
# 7075    developing population codes by minimizing desc...
# 7076    a unified gradient-descent/clustering architec...
# 7077                 transition point dynamic programming
# 7078    structured machine learning for 'soft' classif...
# 7079    strategies for teaching layered networks class...
# 7080    how to describe neuronal activity: spikes rate...
# 7081    learning temporal dependencies in connectionis...
# 7082    emergence of global structure from local assoc...
# 7083    classification of multi-spectral pixels by the...
# 7084    correlation functions in a large stochastic ne...
# 7085    classification of electroencephalogram using a...
# 7086    postal address block location using a convolut...
# 7087    learning complex boolean functions: algorithms...
# 7088    lipreading by neural networks: visual preproce...
# 7089                 connectionism for music and audition
# 7090    spontaneous and  information-triggered segment...
# 7091             encoding labeled graphs by labeling raam
# 7092       speaker recognition using neural tree networks
# 7093    non-linear statistical analysis and self-organ...
# 7094    non-intrusive gaze tracking using artificial n...
# 7095    digital boltzmann vlsi for constraint satisfac...
# 7096    monte carlo matrix inversion and reinforcement...
# 7097    two-dimensional object localization by coarse-...
# 7098    the role of mt neuron receptive field surround...
# 7099    development of orientation and ocular dominanc...
# 7100    two iterative algorithms for computing the sin...
# 7101    high order neural networks for efficient assoc...
# 7102    robot learning: exploration and continuous dom...
# 7103    comparison training for a rescheduling problem...
# 7104               exploiting chaos to control the future
# 7105    generation of internal representation by -tran...
# 7106                 how to choose an activation function
# 7107    efficient computation of complex distance metr...
# 7108    illumination-invariant face recognition with a...
# 7109    the "softmax" nonlinearity: derivation using s...
# 7110    learning stochastic perceptrons under k-blocki...
# 7111    nonlinear image interpolation using manifold l...
# 7112      speech recognition experiments with perceptrons
# 7113    using a saliency map for active spatial select...
# 7114    analysis of unstandardized contributions in cr...
# 7115    effects of noise on convergence and generaliza...
# 7116    pairwise neural network classifiers with proba...
# 7117    spatial representations in the parietal cortex...
# 7118    a comparison of discrete-time operator models ...
# 7119    implementation of neural hardware with the neu...
# 7120          finding structure in reinforcement learning
# 7121    a novel reinforcement model of birdsong vocali...
# 7122    reinforcement learning methods for continuous-...
# 7123    neural network implementation approaches for t...
# 7124    a model of the neural basis of the rat's sense...
# 7125    morphogenesis of the lateral geniculate nucleu...
# 7126    glove-talkii: mapping hand gestures to speech ...
# 7127       a growing neural gas network learns topologies
# 7128    jpmax: learning to recognize moving objects as...
# 7129              factorial learning and the em algorithm
# 7130    learning local error bars for nonlinear regres...
# 7131    predictive coding with neural nets: applicatio...
# 7132    direction selectivity in primary visual cortex...
# 7133    simplifying neural nets by discovering flat mi...
# 7134                        learning on a general network
# 7135                               phasor neural networks
# 7136           active learning for function approximation
# 7137    higher order statistical decorrelation without...
# 7138    a neural model of delusions and hallucinations...
# 7139                                       a silicon axon
# 7140    a solvable connectionist model of immediate re...
# 7141    h optimal training algorithms and their relati...
# 7142         an alternative model for mixtures of experts
# 7143      classifying with gaussian mixtures and clusters
# 7144    the use of dynamic writing information in a co...
# 7145    forward dynamic models in human motor control:...
# 7146    scaling properties of coarse-coded symbol memo...
# 7147    unsupervised classification of 3d objects from...
# 7148    a study of parallel perturbative gradient descent
# 7149    advantage updating applied to a differential game
# 7150               generalisation in feedforward networks
# 7151    a rigorous analysis of linsker-type hebbian le...
# 7152    template-based algorithms for connectionist ru...
# 7153    an actor/critic algorithm that is equivalent t...
# 7154    temporal dynamics of generalization in neural ...
# 7155    limits on learning machine accuracy imposed by...
# 7156              diffusion of credit in markovian models
# 7157                 murphy: a robot that learns by doing
# 7158    the ni1000: high speed parallel vlsi for imple...
# 7159                   pca-pyramids for image compression
# 7160    learning saccadic eye movements using multisca...
# 7161    extracting rules from artificial neural networ...
# 7162    from data distributions to regularization in i...
# 7163    on the computational complexity of networks of...
# 7164                          optimal movement primitives
# 7165    reinforcement learning predicts the site of pl...
# 7166    hierarchical mixtures of experts methodology a...
# 7167    a computationally robust anatomical model for ...
# 7168        financial applications of learning from hints
# 7169    asymptotics of gradient-based neural network t...
# 7170    instance-based state identification for reinfo...
# 7171    learning with preknowledge: clustering with po...
# 7172    dynamic modelling of chaotic time series with ...
# 7173                   a model for chemosensory reception
# 7174    sardnet: a self-organizing feature map for seq...
# 7175    estimating conditional probability densities f...
# 7176       learning prototype models for tangent distance
# 7177    learning with temporal derivatives in pulse-co...
# 7178    direct multi-step time series prediction using...
# 7179    deterministic annealing variant of the em algo...
# 7180    patterns of damage in neural networks: the eff...
# 7181                                 phase-space learning
# 7182    synchrony and desynchrony in neural oscillator...
# 7183    the electrotonic transformation: a tool for re...
# 7184    boosting the performance of rbf networks with ...
# 7185    a charge-based cmos parallel analog vector qua...
# 7186    computational structure of coordinate transfor...
# 7187    inferring ground truth from subjective labelli...
# 7188    alvinn: an autonomous land vehicle in a neural...
# 7189    using voice transformations to create addition...
# 7190    reinforcement learning algorithm for partially...
# 7191    hyperparameters evidence and generalisation fo...
# 7192    a non-linear information maximisation algorith...
# 7193    anatomical origin and computational role of di...
# 7194            factorial learning by clustering features
# 7195    predicting the risk of complications in corona...
# 7196    an analog neural network inspired by fractal b...
# 7197    a lagrangian formulation for optical backpropa...
# 7198    learning many related tasks at the same time w...
# 7199    non-linear prediction of acoustic vectors usin...
# 7200    transformation invariant autoassociation with ...
# 7201    recognizing handwritten digits using mixtures ...
# 7202    an auditory localization and coordinate transf...
# 7203                     an input output hmm architecture
# 7204    learning from queries for maximum information ...
# 7205            boltzmann chains and hidden markov models
# 7206    an integrated architecture of adaptive neural ...
# 7207    capacity and information efficiency of a brain...
# 7208    adaptive elastic input field for recognition i...
# 7209    neural analog diffusion-enhancement layer and ...
# 7210    sample size requirements for feedforward neura...
# 7211    combining estimators using non-constant weight...
# 7212    a model of the hippocampus combining self-orga...
# 7213    catastrophic interference in human motor learning
# 7214    model of a biological neuron as a temporal neu...
# 7215                              dynamic cell structures
# 7216                      on-line learning of dichotomies
# 7217    new algorithms for 2d and 3d point matching: p...
# 7218                          pattern playback in the 90s
# 7219    learning in large linear perceptrons and why t...
# 7220    spreading activation over distributed microfea...
# 7221    interior point implementations of alternating ...
# 7222    reinforcement learning with soft state aggrega...
# 7223    coarse-to-fine image search using neural networks
# 7224        on the computational utility of consciousness
# 7225          a convolutional neural network hand tracker
# 7226    efficient methods for dealing with missing dat...
# 7227        grammar learning by a self-organizing network
# 7228    recurrent networks: second order properties an...
# 7229    comparing the prediction accuracy of artificia...
# 7230     convergence properties of the k-means algorithms
# 7231    analog implementation of shunting neural networks
# 7232                          learning with product units
# 7233    stochastic dynamics of three-state neural netw...
# 7234    grouping components of three-dimensional movin...
# 7235    visual speech recognition with stochastic netw...
# 7236                  single transistor learning synapses
# 7237    bias variance and the combination of least squ...
# 7238            a real time clustering cmos neural engine
# 7239    learning direction in global motion: two class...
# 7240    correlation and interpolation networks for rea...
# <PIL.Image.Image image mode=RGB size=400x200 at 0x23E91325550>

# %% [markdown]
# ## 6.  Prepare the text for LDA analysis
# <p>The main text analysis method that we will use is latent Dirichlet allocation (LDA). LDA is able to perform topic detection on large document sets, determining what the main 'topics' are in a large unlabeled set of texts. A 'topic' is a collection of words that tend to co-occur often. The hypothesis is that LDA might be able to clarify what the different topics in the research titles are. These topics can then be used as a starting point for further analysis.</p>
# <p>LDA does not work directly on text data. First, it is necessary to convert the documents into a simple vector representation. This representation will then be used by LDA to determine the topics. Each entry of a 'document vector' will correspond with the number of times a word occurred in the document. In conclusion, we will convert a list of titles into a list of vectors, all with length equal to the vocabulary. For example, <em>'Analyzing machine learning trends with neural networks.'</em> would be transformed into <code>[1, 0, 1, ..., 1, 0]</code>.</p>
# <p>We'll then plot the 10 most common words based on the outcome of this operation (the list of document vectors). As a check, these words should also occur in the word cloud.</p>

# %%
# Load the library with the CountVectorizer method
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np

# Helper function
def plot_10_most_common_words(count_data, count_vectorizer):
    import matplotlib.pyplot as plt
    words = count_vectorizer.get_feature_names()
    total_counts = np.zeros(len(words))
    for t in count_data:
        total_counts+=t.toarray()[0]
    
    count_dict = (zip(words, total_counts))
    count_dict = sorted(count_dict, key=lambda x:x[1], reverse=True)[0:10]
    words = [w[0] for w in count_dict]
    counts = [w[1] for w in count_dict]
    x_pos = np.arange(len(words)) 

    plt.bar(x_pos, counts,align='center')
    plt.xticks(x_pos, words, rotation=90) 
    plt.xlabel('words')
    plt.ylabel('counts')
    plt.title('10 most common words')
    plt.show()

# Initialise the count vectorizer with the English stop words
count_vectorizer = CountVectorizer()

# Fit and transform the processed titles
count_data = count_vectorizer.fit_transform(papers['title_processed'])

# Visualise the 10 most common words
plot_10_most_common_words(count_data, count_vectorizer)

# %% [markdown]
# ## 7. Analysing trends with LDA
# <p>Finally, the research titles will be analyzed using LDA. Note that in order to process a new set of documents (e.g. news articles), a similar set of steps will be required to preprocess the data. The flow that was constructed here can thus easily be exported for a new text dataset.</p>
# <p>The only parameter we will tweak is the number of topics in the LDA algorithm. Typically, one would calculate the 'perplexity' metric to determine which number of topics is best and iterate over different amounts of topics until the lowest 'perplexity' is found. For now, let's play around with a different number of topics. From there, we can distinguish what each topic is about ('neural networks', 'reinforcement learning', 'kernel methods', 'gaussian processes', etc.).</p>

# %%
import warnings
warnings.simplefilter("ignore", DeprecationWarning)

# Load the LDA model from sk-learn
from sklearn.decomposition import LatentDirichletAllocation as LDA
 
# Helper function
def print_topics(model, count_vectorizer, n_top_words):
    words = count_vectorizer.get_feature_names()
    for topic_idx, topic in enumerate(model.components_):
        print("\nTopic #%d:" % topic_idx)
        print(" ".join([words[i]
                        for i in topic.argsort()[:-n_top_words - 1:-1]]))
        
# Tweak the two parameters below (use int values below 15)
number_topics = ...
number_words = ...

# Create and fit the LDA model
lda = LDA(n_components=number_topics)
lda.fit(count_data)

# Print the topics found by the LDA model
print("Topics found via LDA:")
print_topics(lda, count_vectorizer, number_words)
# Out:
# Topics found via LDA:
#
# Topic #0:
# in visual feature structured of and distributed the model based machine
#
# Topic #1:
# of and non for image model the using scale search human
#
# Topic #2:
# learning for models with sparse efficient and in of by convex
#
# Topic #3:
# random monte carlo adversarial bayesian without action exploration topic end improving
#
# Topic #4:
# deep learning supervised networks in semi brain with theory neural fields
#
# Topic #5:
# for gaussian regression classification processes process learning method graph algorithms and
#
# Topic #6:
# the of on optimization for kernel and estimation convergence approximation methods
#
# Topic #7:
# via multi algorithm probabilistic selection modeling detection adaptive robust for task
#
# Topic #8:
# learning for networks neural in with and of on stochastic inference
#
# Topic #9:
# of the in bounds local neurons as rank generalization bandits through
#
# Topic #10:
# of from to learning with analysis for data and an information
#
# Topic #11:
# for clustering markov learning structure multiple decision object spectral regularization minimization

# %% [markdown]
# ## 8. The future of machine learning
# <p>Machine learning has become increasingly popular over the past years. The number of NIPS conference papers has risen exponentially, and people are continuously looking for ways on how they can incorporate machine learning into their products and services.</p>
# <p>Although this analysis focused on analyzing machine learning trends in research, a lot of these techniques are rapidly being adopted in industry. Following the latest machine learning trends is a critical skill for a data scientist, and it is recommended to continuously keep learning by going through blogs, tutorials, and courses.</p>

# %%
# The historical data indicates that:
more_papers_published_in_2018 = True

# %%
We can see in task 3 that the number of papers published each year are increasing. 
Therefore it is more likely that the papers published in 2018 would be more than papers published in 2017.
